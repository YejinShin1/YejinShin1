# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### rpart na imputation data correlation

# %%
data_rpart = pd.read_csv("C:/Users/Rstudio/Desktop/문화분석/국민여가활동조사/data2019_rev_rpart_transformation_scaling.csv")
data.head()
# Out:
#       Attr1     Attr2     Attr3     Attr4     Attr5     Attr6  Attr7  Attr8  \
# 0 -1.000099  2.232022 -1.251384 -1.919573  6.783539  2.083603      1      0
# 1 -1.000099  2.232022 -1.251384 -1.471681  4.297095  1.076820      0      1
# 2  1.378200 -0.282346 -1.251384  1.801374 -0.653742 -1.435140      1      1
# 3  0.585434  0.555777 -1.251384  1.008950  0.066769  0.850724      1      0
# 4 -0.207333 -0.282346  0.540889 -0.670644 -1.045095  0.137325      1      1
#
#       Attr9  Attr10  ...  Attr31  Attr32  Attr33  Attr34  Attr35  Attr36  \
# 0  1.478228       1  ...       1       1       1       1       0       1
# 1  0.681496       1  ...       1       1       1       1       0       1
# 2  1.034056       0  ...       0       1       0       0       1       1
# 3  1.034056       1  ...       1       1       0       0       1       1
# 4  0.681496       0  ...       1       1       1       1       0       1
#
#    Attr37  Attr38  Attr39  Satisf
# 0       1       1       1       1
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data_rpart.corr(), annot=True)

# %%
data.columns[data.corr()["Attr18"]>=0.7]
# Out:
# Index(['Attr18'], dtype='object')

# %%
for i in range(1, data_rpart.shape[1]):
    print("High correlation with Attr", i, "is: ")
    print(list(data_rpart.columns[(data_rpart.corr()["Attr{}".format(i)]>=0.7)|
                            (data_rpart.corr()["Attr{}".format(i)]<=-0.7)]))
# Out:
# High correlation with Attr 1 is:
# ['Attr1']
# High correlation with Attr 2 is:
# ['Attr2']
# High correlation with Attr 3 is:
# ['Attr3']
# High correlation with Attr 4 is:
# ['Attr4']
# High correlation with Attr 5 is:
# ['Attr5']
# High correlation with Attr 6 is:
# ['Attr6']
# High correlation with Attr 7 is:
# ['Attr7']
# High correlation with Attr 8 is:
# ['Attr8']
# High correlation with Attr 9 is:
# ['Attr9', 'Attr11']
# High correlation with Attr 10 is:
# ['Attr10']
# High correlation with Attr 11 is:
# ['Attr9', 'Attr11']
# High correlation with Attr 12 is:
# ['Attr12']
# High correlation with Attr 13 is:
# ['Attr13']
# High correlation with Attr 14 is:
# ['Attr14']
# High correlation with Attr 15 is:
# ['Attr15']
# High correlation with Attr 16 is:
# ['Attr16']
# High correlation with Attr 17 is:
# ['Attr17']
# High correlation with Attr 18 is:
# ['Attr18']
# High correlation with Attr 19 is:
# ['Attr19']
# High correlation with Attr 20 is:
# ['Attr20']
# ...

# %%
### Attr9와 Attr11
data_rpart['Attr9'].corr(data_rpart['Attr11'])
# Out:
# 0.78505924569494

# %% [markdown]
# ### knn na imputation data correlation

# %%
data_knn = pd.read_csv("C:/Users/Rstudio/Desktop/문화분석/국민여가활동조사/data2019_rev_knn_transformation_scaling.csv")
data.head()
# Out:
#       Attr1     Attr2     Attr3     Attr4     Attr5     Attr6  Attr7  Attr8  \
# 0 -1.000099  2.232022 -1.251384 -1.919573  6.783539  2.083603      1      0
# 1 -1.000099  2.232022 -1.251384 -1.471681  4.297095  1.076820      0      1
# 2  1.378200 -0.282346 -1.251384  1.801374 -0.653742 -1.435140      1      1
# 3  0.585434  0.555777 -1.251384  1.008950  0.066769  0.850724      1      0
# 4 -0.207333 -0.282346  0.540889 -0.670644 -1.045095  0.137325      1      1
#
#       Attr9  Attr10  ...  Attr31  Attr32  Attr33  Attr34  Attr35  Attr36  \
# 0  1.478228       1  ...       1       1       1       1       0       1
# 1  0.681496       1  ...       1       1       1       1       0       1
# 2  1.034056       0  ...       0       1       0       0       1       1
# 3  1.034056       1  ...       1       1       0       0       1       1
# 4  0.681496       0  ...       1       1       1       1       0       1
#
#    Attr37  Attr38  Attr39  Satisf
# 0       1       1       1       1
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data_knn.corr(), annot=True)

# %%
for i in range(1, data_knn.shape[1]):
    print("High correlation with Attr", i, "is: ")
    print(list(data_knn.columns[(data_knn.corr()["Attr{}".format(i)]>=0.7)|
                            (data_knn.corr()["Attr{}".format(i)]<=-0.7)]))
# Out:
# High correlation with Attr 1 is:
# ['Attr1']
# High correlation with Attr 2 is:
# ['Attr2']
# High correlation with Attr 3 is:
# ['Attr3']
# High correlation with Attr 4 is:
# ['Attr4']
# High correlation with Attr 5 is:
# ['Attr5']
# High correlation with Attr 6 is:
# ['Attr6']
# High correlation with Attr 7 is:
# ['Attr7']
# High correlation with Attr 8 is:
# ['Attr8']
# High correlation with Attr 9 is:
# ['Attr9', 'Attr11']
# High correlation with Attr 10 is:
# ['Attr10']
# High correlation with Attr 11 is:
# ['Attr9', 'Attr11']
# High correlation with Attr 12 is:
# ['Attr12']
# High correlation with Attr 13 is:
# ['Attr13']
# High correlation with Attr 14 is:
# ['Attr14']
# High correlation with Attr 15 is:
# ['Attr15']
# High correlation with Attr 16 is:
# ['Attr16']
# High correlation with Attr 17 is:
# ['Attr17']
# High correlation with Attr 18 is:
# ['Attr18']
# High correlation with Attr 19 is:
# ['Attr19']
# High correlation with Attr 20 is:
# ['Attr20']
# ...

# %%
### Attr9와 Attr11
data_knn['Attr9'].corr(data_knn['Attr11'])
# Out:
# 0.78505924569494

# %% [markdown]
# Attr9: Q9 월평균 여가활동 지출액
#
# Attr11: Q10 적절하다고 생각하는 여가비용(월평균)
#
# 결론: 사람들은 자신이 적절하다고 생각하는 것만큼 실제로 지출한다
